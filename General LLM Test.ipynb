# %%
# ══════════════════════════════════════════════════════════════════════════════
# CELL 1: Configuration and Setup
# ══════════════════════════════════════════════════════════════════════════════

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Configuration - UPDATE THESE PATHS
CHROMA_DB_DIR = "/content/drive/MyDrive/BirdNET_Singapore/chromadb"  # Update to your path
ANTHROPIC_API_KEY = "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"  # Update with your API key
EMBEDDING_MODEL = "all-MiniLM-L6-v2"

print("✅ Configuration set")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Configuration set

# %%
# ══════════════════════════════════════════════════════════════════════════════
# CELL 2: General LLM Functions (No Retrieval)
# ══════════════════════════════════════════════════════════════════════════════

def get_bird_explanation_GENERAL(species: str, confidence: float) -> str:
    prompt = f"""You are a knowledgeable bird guide.

A bird sound recognition system has identified:
Species: {species}
Confidence: {confidence:.0%}

Write a friendly, educational response (150–200 words) covering:
1. A brief physical description
2. Where it can be found
3. Its resident/migratory status
4. Its conservation status and any interesting facts

Warm, engaging tone for nature enthusiasts."""

    response = claude.messages.create(
        model="claude-sonnet-4-20250514",
        max_tokens=400,
        messages=[{"role": "user", "content": prompt}]
    )
    return response.content[0].text


def ask_about_bird_GENERAL(question: str, species: str = None) -> str:
    species_context = f" about {species}" if species else ""

    prompt = f"""You are a knowledgeable bird guide.

Answer this question{species_context}:

Question: {question}

Guidelines:
- Be factual and concise (under 200 words)
- If you're unsure, say so honestly
- Warm, engaging tone for nature enthusiasts"""

    response = claude.messages.create(
        model="claude-sonnet-4-20250514",
        max_tokens=400,
        messages=[{"role": "user", "content": prompt}]
    )
    return response.content[0].text

print("✅ General LLM functions defined")
# Out:
# ✅ General LLM functions defined

# %%
# ══════════════════════════════════════════════════════════════════════════════
# CELL 3: Test 1 - Species Explanation (Tiger Shrike)
# ══════════════════════════════════════════════════════════════════════════════

print("=" * 70)
print("TEST 1: Bird detection explanation (Tiger Shrike, 87% confidence)")
print("=" * 70)
print("\n GENERAL LLM RESPONSE (no retrieval):\n")
print(get_bird_explanation_GENERAL("Tiger Shrike", confidence=0.87))
# Out:
# ...
# TEST 1: Bird detection explanation (Tiger Shrike, 87% confidence)
# ...
#
# 🔵 GENERAL LLM RESPONSE (no retrieval):
#
# What an exciting identification! The Tiger Shrike is a striking bird that lives up to its fierce name. This medium-sized shrike displays beautiful russet-brown plumage with distinctive black barring across its back and wings, giving it that "tiger-striped" appearance. Males sport a bold black mask through their eyes, while females show more subdued coloring.
#
# You'll find Tiger Shrikes across East Asia, from eastern Russia and China down through Korea and into Southeast Asia. They're primarily migratory birds, breeding in the northern parts of their range during summer and heading south to warmer regions like Thailand, Malaysia, and southern China for winter.
#
# Currently listed as "Least Concern" by conservation organizations, Tiger Shrikes are doing relatively well, though habitat loss remains a concern in some areas.
#
# ...

# %%
# ══════════════════════════════════════════════════════════════════════════════
# CELL 4: Test 2 - Species-Specific Question (Collared Kingfisher)
# ══════════════════════════════════════════════════════════════════════════════

print("=" * 70)
print("TEST 2: Species-specific question (Collared Kingfisher habitat)")
print("=" * 70)
print("\n🔵 GENERAL LLM RESPONSE (no retrieval):\n")
print(ask_about_bird_GENERAL("Where can I spot this bird?", species="Collared Kingfisher"))
# Out:
# ...
# TEST 2: Species-specific question (Collared Kingfisher habitat)
# ...
#
# 🔵 GENERAL LLM RESPONSE (no retrieval):
#
# The Collared Kingfisher is wonderfully widespread across tropical Asia and the western Pacific! You'll find these striking blue-and-white birds from India and Southeast Asia through Indonesia, the Philippines, and out to many Pacific islands including northern Australia.
#
# Unlike their fish-loving cousins, Collared Kingfishers are quite adaptable about habitat. Look for them in:
#
# - **Coastal areas** - mangroves, beaches, and tidal flats
# - **Urban parks and gardens** with large trees
# - **Forest edges** and clearings
# - **Rice paddies** and agricultural areas
# - **Wooded areas** near water sources
#
# They're often spotted perched prominently on power lines, dead branches, or posts, scanning for insects, small crabs, and lizards. Listen for their loud, rattling call - it's quite distinctive!
#
# ...

# %%
# ══════════════════════════════════════════════════════════════════════════════
# CELL 5: Test 3 - Migratory Birds Question
# ══════════════════════════════════════════════════════════════════════════════

print("=" * 70)
print("TEST 3: General question (migratory birds in Singapore)")
print("=" * 70)
print("\n🔵 GENERAL LLM RESPONSE (no retrieval):\n")
print(ask_about_bird_GENERAL("Which birds in Singapore are migratory?"))
# Out:
# ...
# TEST 3: General question (migratory birds in Singapore)
# ...
#
# 🔵 GENERAL LLM RESPONSE (no retrieval):
#
# Singapore hosts many fascinating migratory birds, particularly during the October-March winter months when species escape colder northern regions!
#
# **Common migrants include:**
# - **Raptors**: Chinese Goshawk, Japanese Sparrowhawk, and Grey-faced Buzzard pass through during spectacular migration periods
# - **Shorebirds**: Various sandpipers, plovers, and turnstones stop at mudflats and coastlines
# - **Forest birds**: Asian Paradise Flycatcher, Tiger Shrike, and several warbler species
# - **Waterbirds**: Northern Pintail, Garganey ducks, and Chinese Pond Heron
#
# The **Sungei Buloh Wetland Reserve** is Singapore's premier migration hotspot, where thousands of shorebirds refuel during their epic journeys between Arctic breeding grounds and Australian wintering areas.
#
# ...

# %%
# ══════════════════════════════════════════════════════════════════════════════
# CELL 6: Test 4 - Conservation Question
# ══════════════════════════════════════════════════════════════════════════════

print("=" * 70)
print("TEST 4: Conservation question (endangered species in Singapore)")
print("=" * 70)
print("\n🔵 GENERAL LLM RESPONSE (no retrieval):\n")
print(ask_about_bird_GENERAL("Which birds in Singapore are endangered or threatened?"))
# Out:
# ...
# TEST 4: Conservation question (endangered species in Singapore)
# ...
#
# 🔵 GENERAL LLM RESPONSE (no retrieval):
#
# Singapore faces significant challenges in bird conservation due to rapid urbanization and habitat loss. Several species are critically endangered or threatened:
#
# **Critically Endangered:**
# - **Straw-headed Bulbul** - Once common, now extremely rare due to the illegal bird trade
# - **Singapore Freshwater Crab Plover** - Actually, I should clarify - this specific species doesn't exist, but several shorebirds face threats
#
# **Threatened/Vulnerable:**
# - **Black-winged Flycatcher-shrike** - Habitat loss has severely impacted populations
# - **Changeable Hawk-Eagle** - Very few breeding pairs remain
# - **Various terns and shorebirds** - Including the Little Tern, affected by coastal development
#
# **Of Special Concern:**
# - **Oriental Pied Hornbill** - Making a comeback thanks to conservation efforts, but still vulnerable
# ...

# %%
# ══════════════════════════════════════════════════════════════════════════════
# CELL 7: Test 5 - Habitat Question
# ══════════════════════════════════════════════════════════════════════════════

print("=" * 70)
print("TEST 5: Habitat question (mangrove birds in Singapore)")
print("=" * 70)
print("\n🔵 GENERAL LLM RESPONSE (no retrieval):\n")
print(ask_about_bird_GENERAL("Which birds can be found in mangroves in Singapore?"))
# Out:
# ...
# TEST 5: Habitat question (mangrove birds in Singapore)
# ...
#
# 🔵 GENERAL LLM RESPONSE (no retrieval):
#
# Singapore's mangroves are fantastic birding spots! Here are some key species you can find:
#
# **Herons & Egrets**: Little Heron, Great Egret, and Intermediate Egret are common sights, especially at dawn and dusk when they're actively fishing.
#
# **Kingfishers**: The stunning Collared Kingfisher is a mangrove specialist, often perched on branches scanning for crabs and fish. White-throated Kingfishers also frequent these areas.
#
# **Sunbirds**: Olive-backed Sunbirds flit among mangrove flowers, particularly when *Sonneratia* trees are blooming.
#
# **Raptors**: Brahminy Kites soar overhead, while White-bellied Sea Eagles (though less common) occasionally patrol the coastline.
#
# **Other notables**: Pacific Swallows hunt insects above the canopy, Pink-necked Green Pigeons feed on fruits, and various bulbuls move through the vegetation.
#
# ...

# %%
your_question = input("Ask anything: ")
your_species = input("Filter to species? (leave blank for all): ").strip() or None
print(ask_about_bird_GENERAL(your_question, species=your_species))
# Out:
# Ask anything: I live in ang mo kio
# Filter to species? (leave blank for all):
# Hello fellow bird enthusiast! Ang Mo Kio is a wonderful area for birdwatching in Singapore. You're in for some great birding opportunities right in your neighborhood!
#
# **Common species you can spot:**
# - **Javan Mynas** and **Common Mynas** - abundant around HDB blocks
# - **Pink-necked Green Pigeons** - look for them in fruiting trees
# - **Yellow-vented Bulbuls** - very common, with their distinctive calls
# - **Oriental Magpie-Robins** - beautiful songbirds often seen in parks
# - **Zebra Doves** - ground-feeding doves with soft cooing calls
#
# **Great birding spots near you:**
# - **Ang Mo Kio Town Garden West** - excellent for various species
# - **Bishan-Ang Mo Kio Park** - fantastic diversity, especially near the river
# - **Upper Seletar Reservoir** area - for waterbirds and forest species
#
# ...

# %%
your_question = input("Ask anything: ")
your_species = input("Filter to species? (leave blank for all): ").strip() or None
print(ask_about_bird_GENERAL(your_question, species=your_species))
# Out:
# Ask anything: what is the cutest bird?
# Filter to species? (leave blank for all):
# What a delightful question! While "cuteness" is wonderfully subjective, several birds consistently melt hearts worldwide.
#
# **Puffins** are strong contenders with their colorful beaks, tuxedo plumage, and clumsy-adorable waddle. Their expressive orange eyes and perpetually curious expression make them irresistible.
#
# **Northern Saw-whet Owls** are impossibly tiny (sparrow-sized!) with enormous golden eyes and fluffy, round bodies that look like living stuffed animals.
#
# **Japanese Long-tailed Tits** resemble floating cotton balls with their incredibly fluffy white plumage and tiny black button eyes.
#
# **Bee Hummingbirds** (world's smallest bird) are so petite they're often mistaken for insects, hovering like jeweled sprites.
#
# **Baby chickens** deserve mention too – those downy yellow fluff balls with their tiny cheeps are universally adored.
#
# ...

# %%
# !lscpu
# Out:
# Architecture:                x86_64
#   CPU op-mode(s):            32-bit, 64-bit
#   Address sizes:             46 bits physical, 48 bits virtual
#   Byte Order:                Little Endian
# CPU(s):                      2
#   On-line CPU(s) list:       0,1
# Vendor ID:                   GenuineIntel
#   Model name:                Intel(R) Xeon(R) CPU @ 2.20GHz
#     CPU family:              6
#     Model:                   79
#     Thread(s) per core:      2
#     Core(s) per socket:      1
#     Socket(s):               1
#     Stepping:                0
#     BogoMIPS:                4400.44
#     Flags:                   fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pg
#                              e mca cmov pat pse36 clflush mmx fxsr sse sse2 ss h
#                              t syscall nx pdpe1gb rdtscp lm constant_tsc rep_goo
#                              d nopl xtopology nonstop_tsc cpuid tsc_known_freq p
# ...
